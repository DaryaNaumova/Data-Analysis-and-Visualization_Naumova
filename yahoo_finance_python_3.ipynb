# %% [markdown]
# <a href="https://colab.research.google.com/github/DaryaNaumova/Data-Analysis-and-Visualization_Naumova/blob/main/yahoo_finance_python_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Шаг 1: Установка необходимых библиотек.**

# %%
# !pip install yfinance matplotlib

# %% [markdown]
# # **Шаг 2: Получение данных о ценах акций.**

# %%
import yfinance as yf
import matplotlib.pyplot as plt
# Получение данных для акций Apple
data = yf.download('MSFT', '2025-01-01', '2025-02-25')
# Визуализация скорректированной цены закрытия

data['Close'].plot()

plt.title('Скорректированная цена закрытия MSF')

plt.xlabel('Дата')

plt.ylabel('Цена')

plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # **Задача 2: Визуализация данных**
# # **Шаг 1: Создание списка тикеров.**

# %%
tickers_list = ['AAPL', 'GOOG', 'MSFT']

# %% [markdown]
# # **Шаг 2: Получение и визуализация данных для нескольких акций.**

# %% [markdown]
# ```
# import pandas as pd
# # Создание DataFrame для хранения данных
# data = pd.DataFrame(columns=tickers_list)
# # Получение данных для каждого тикера
# for ticker in tickers_list:
#
#     data[ticker] = yf.download(ticker, '2020-01-01', '2022-12-31')['Adj Close']
#
# # Визуализация данных
# data.plot(figsize=(10, 7))
# plt.title('Скорректированная цена закрытия')
# plt.xlabel('Дата')
# plt.ylabel('Цена')
# plt.legend()
# plt.show()
# ```
